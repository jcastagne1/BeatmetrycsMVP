# %%
from spotify_client import *

# %%
client_id = '0fbfa1d44348460d9d15a2f434f22527'
client_secret = '4b12f375aed54ab4b50420f1ec381cdb'

# %%
spotify = SpotifyAPI(client_id, client_secret)

# %%
spotify.search({"album":"Post Mortem","artist":"Dillom"},search_type="album")
# Out:
# q=album%3APost+Mortem+artist%3ADillom&type=album

# %%
spotify.get_album("39g3CsFBc9YK9Z6AbvvkgF")

# %%
spotify.get_track("1ylWNC8zMjZTExszCerenj")
